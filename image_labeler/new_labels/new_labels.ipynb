# %%
import pandas as pd
import numpy as np

import random
import string
import os
import boto3
from sqlalchemy import text, create_engine
import requests

from datetime import datetime, timedelta
import random

import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

from concurrent.futures import ThreadPoolExecutor, as_completed

import time
import random
from io import BytesIO

# %%
def download_and_upload(row, label_directory, batch_id):
    index = row.name  # If using iterrows()
    if not row.image_link.startswith('http'):
        return None

    try:
        # Random sleep between 0.5 and 2.5 seconds
        time.sleep(random.uniform(0.5, 2.5))

        response = requests.get(row.image_link, verify=False, timeout=10)
        if response.status_code == 200:
            file_name = f"{row.asset_id}.jpg"
            file_path = os.path.join(label_directory, file_name)
            
            with open(file_path, 'wb') as f:
                f.write(response.content)

            s3.upload_file(file_path, 'clip-art-monster-images-for-labeling', f"batch_{batch_id}/{file_name}")
            return index
        else:
            print(f"[{index}] Failed: Status code {response.status_code}")
    except Exception as e:
        print(f"[{index}] Exception: {e}")
    return None

db_connection_string = "postgresql+pg8000://clipart_monster_db_user:iV0BUFPv0rMLu5MKVXesLlvFT3E6MneJ@dpg-cocp8eq0si5c73an4rp0-a.ohio-postgres.render.com/clipart_monster_db_prod"
db_connection_string_dev = "postgresql+pg8000://clipart_monster_db_user:iV0BUFPv0rMLu5MKVXesLlvFT3E6MneJ@dpg-cocp8eq0si5c73an4rp0-a.ohio-postgres.render.com/clipart_monster_db"

# %%
engine = create_engine(db_connection_string)
engine_dev = create_engine(db_connection_string_dev)

# %%
with engine_dev.connect() as connection_dev:
    label_image_table = pd.read_sql('SELECT * FROM "label_data.selected_assets_new"', connection_dev)

with engine.connect() as connection_prod:
    filtered_assets = pd.read_sql('''
        SELECT a.asset_id, a.image_link
        FROM "content"."assets" a
        JOIN (
            SELECT asset_id FROM "model_predictions"."multi_color"
        ) m ON a.asset_id = m.asset_id
        WHERE a.s3 = TRUE
    ''', connection_prod)
image_links = filtered_assets[["asset_id", "image_link"]].sample(1000)

# %%
with engine.connect() as connection_prod:
    filtered_assets = pd.read_sql('''
        SELECT a.asset_id, a.image_link
        FROM "content"."assets" a
        JOIN (
            SELECT asset_id FROM "model_predictions"."rule_labels"
            where task_type = 'color_fill_type'
            and rule_index = 2
            and probability > .5
        ) m ON a.asset_id = m.asset_id
        WHERE a.s3 = TRUE
    ''', connection_prod)
image_links2 = filtered_assets[["asset_id", "image_link"]].sample(1000)

# %%
image_links = pd.concat([image_links, image_links2])

# %%
######################
# increment batch id by 1
batch_id = np.max(label_image_table.batch_id) + 1

######################
#remove already selected assets
is_selected= label_image_table \
    .filter(['asset_id']) \
    .assign(selected = 'yes')

avaiable_assets = filtered_assets \
    .merge(image_links, on = 'asset_id', how = 'left') \
    .merge(is_selected, on = 'asset_id', how = 'left') \
    .query('selected != "yes"') \
    .rename(columns={'image_link_x': 'image_link'})




# #set the label directory
# label_directory =  'C:/Users/noahs/Documents/labeling/batch_' + str(batch_id) + '/'

# os.makedirs(label_directory)

# %%
avaiable_assets
# Out:
#          asset_id                                         image_link  \
# 0         7171110  https://banner2.cleanpng.com/cb4/qph/ubx/v9ys0...
# 1         7171111  https://banner2.cleanpng.com/cb4/mzc/znc/v9a43...
# 2         7171112  https://banner2.cleanpng.com/cb4/lcq/vuj/v9ymm...
# 3         7171113  https://banner2.cleanpng.com/cb4/uaq/ddi/v9xbn...
# 4         7171114  https://banner2.cleanpng.com/cb3/sxs/vte/v9xzl...
# ...           ...                                                ...
# 1002273   7146284  https://banner2.cleanpng.com/cb3/dnv/ttu/v9vbk...
# 1002274   7146285  https://banner2.cleanpng.com/cb4/cce/frx/v9vtg...
# 1002275   7146287  https://banner2.cleanpng.com/cb4/ojq/szn/v9vj1...
# 1002277   7146292  https://banner2.cleanpng.com/cb2/xxv/bkn/v9vt1...
# 1002278   7146318  https://elements-resized.envatousercontent.com...
#
#         image_link_y selected
# 0                NaN      NaN
# 1                NaN      NaN
# 2                NaN      NaN
# ...

# %%
######################
# CONFIG — set these before running
TASK_TYPE = 'color_fill_type'
RULE_INDEX = 5
BATCH_ID = 1
SUB_BATCH_SIZE = 500      # assets per large_sub_batch
SAMPLE_COUNT = 2000      # total assets to sample
######################

date = datetime.now().strftime("%Y-%m-%d")

# Find the current max large_sub_batch for this task/rule/batch
with engine_dev.connect() as conn:
    max_lsb_result = pd.read_sql(text("""
        SELECT COALESCE(MAX(large_sub_batch), 0) as max_lsb
        FROM "label_data.selected_assets_new"
        WHERE task_type = :task_type AND rule_index = :rule_index AND batch_id = :batch_id
    """), conn, params={'task_type': TASK_TYPE, 'rule_index': RULE_INDEX, 'batch_id': BATCH_ID})
    max_lsb = int(max_lsb_result['max_lsb'].iloc[0])

print(f"Current max large_sub_batch for {TASK_TYPE} rule {RULE_INDEX} batch {BATCH_ID}: {max_lsb}")
print(f"New sub-batches will start at {max_lsb + 1}")

selected_assets = avaiable_assets \
    .rename(columns={'image_link_x': 'image_link'}) \
    .sample(SAMPLE_COUNT) \
    .filter(['asset_id','image_link']) \
    .assign(batch_id = BATCH_ID) \
    .assign(date_created = date) \
    .assign(label_count = 0) \
    .assign(clip_art_type = 0) \
    .assign(count = 0) \
    .assign(line_width = 0) \
    .assign(color_depth = 0) \
    .assign(primary_color = 0) \
    .reset_index() \
    .drop(['index'],axis = 1)

temp = selected_assets.copy().reset_index(drop=True)

# Use a positional counter (np.arange), NOT temp.index: a non-contiguous index
# (from a filtered/sampled subset) would scatter assets into sparse, high
# large_sub_batch numbers.
_pos = np.arange(len(temp))
temp['sub_batch'] = ((_pos // 5) + 1).astype(int)
temp['large_sub_batch'] = ((_pos // SUB_BATCH_SIZE) + 1 + max_lsb).astype(int)
temp['asset_type'] = 'undetermined'
temp['color_type'] = 'undetermined'
temp['multi_element'] = 'undetermined'
temp['task_type'] = TASK_TYPE
temp['rule_index'] = RULE_INDEX

print(f"Created {len(temp)} assets in sub-batches {max_lsb + 1} – {temp['large_sub_batch'].max()}")
# Out:
# Current max large_sub_batch for color_fill_type rule 5 batch 1: 0
# New sub-batches will start at 1
# Created 2000 assets in sub-batches 1 – 4

# %%
temp
# Out:
#       asset_id                                         image_link  batch_id  \
# 0      4361175  https://t4.ftcdn.net/jpg/08/39/05/59/360_F_839...         1
# 1      2094081  https://t4.ftcdn.net/jpg/02/88/59/25/360_F_288...         1
# 2      9411979  https://images.rawpixel.com/image_800/cHJpdmF0...         1
# 3      9410600  https://img.b2bpic.net/premium-vector/cute-wre...         1
# 4     10649627  https://images.rawpixel.com/image_png_800/cHJp...         1
# ...        ...                                                ...       ...
# 1995   8843623  https://img.b2bpic.net/premium-vector/drawing-...         1
# 1996   2095925        https://clipart-library.com/img/1118033.png         1
# 1997   8622458  https://img.b2bpic.net/premium-vector/greek-go...         1
# 1998   8734235  https://us.123rf.com/450wm/memetiqaosvor/memet...         1
# 1999   7930723  https://img.b2bpic.net/premium-photo/scar-fabr...         1
#
# ...

# %%
chunksize = 65535 // len(temp.columns)

temp.to_sql(
    "label_data.selected_assets_new",
    con=engine_dev,
    if_exists="append",
    index=False,
    method="multi",
    chunksize=chunksize
)
# Out:
# 2000

# %%
import pandas as pd
import numpy as np
import time

from sqlalchemy import create_engine, text

DB_CONNECTION_PROD = "postgresql+pg8000://clipart_monster_db_user:iV0BUFPv0rMLu5MKVXesLlvFT3E6MneJ@dpg-cocp8eq0si5c73an4rp0-a.ohio-postgres.render.com/clipart_monster_db_prod"
DB_CONNECTION_DEV = "postgresql+pg8000://clipart_monster_db_user:iV0BUFPv0rMLu5MKVXesLlvFT3E6MneJ@dpg-cocp8eq0si5c73an4rp0-a.ohio-postgres.render.com/clipart_monster_db"

engine = create_engine(DB_CONNECTION_PROD)
engine_dev = create_engine(DB_CONNECTION_DEV)

connection = engine.connect()
connection_dev = engine_dev.connect()

# %%
with engine.connect() as connection_prod:
    photos = pd.read_sql("SELECT * FROM model_predictions.rule_labels where model_version = 'A1_0.09' and probability > .94", connection_prod)

# %%
query = """
SELECT * FROM "label_data.selected_assets_new" where task_type != 'asset_type'
"""

with engine_dev.connect() as connection_dev:
    selected_assets = pd.read_sql(query, connection_dev)

ids_to_delete = selected_assets.merge(photos, on = 'asset_id', how = 'inner')['asset_id'].tolist()

# %%
ids_to_delete
# Out:
# []

# %%
query = """
SELECT * FROM "label_data.selected_assets_new" where task_type != 'asset_type'
"""

with engine_dev.connect() as connection_dev:
    selected_assets = pd.read_sql(query, connection_dev)

ids_to_delete = selected_assets.merge(photos, on = 'asset_id', how = 'inner')['asset_id'].tolist()

placeholders = ', '.join([f':id{i}' for i in range(len(ids_to_delete))])
query = text(f"""DELETE FROM "label_data.selected_assets_new" WHERE asset_id IN ({placeholders})""")
params = {f'id{i}': v for i, v in enumerate(ids_to_delete)}

with engine_dev.connect() as connection_dev:
    connection_dev.execute(query, params)
    connection_dev.commit()

# %%
query = """
SELECT * FROM "label_data.prompt_responses" where task_type != 'asset_type'
"""

with engine_dev.connect() as connection_dev:
    selected_assets = pd.read_sql(query, connection_dev)

ids_to_delete = selected_assets.merge(photos, on = 'asset_id', how = 'inner')['asset_id'].tolist()

# %%
ids_to_delete
# Out:
# []

# %%
query = """
SELECT * FROM "label_data.prompt_responses" where task_type != 'asset_type'
"""

with engine_dev.connect() as connection_dev:
    selected_assets = pd.read_sql(query, connection_dev)

ids_to_delete = selected_assets.merge(photos, on = 'asset_id', how = 'inner')['asset_id'].tolist()

placeholders = ', '.join([f':id{i}' for i in range(len(ids_to_delete))])
query = text(f"""DELETE FROM "label_data.prompt_responses" WHERE asset_id IN ({placeholders}) and task_type != 'asset_type'""")
params = {f'id{i}': v for i, v in enumerate(ids_to_delete)}

with engine_dev.connect() as connection_dev:
    connection_dev.execute(query, params)
    connection_dev.commit()

# %%
query = """
SELECT * FROM "label_data.prompt_responses" where task_type != 'asset_type'
"""

with engine_dev.connect() as connection_dev:
    prompt_responses = pd.read_sql(query, connection_dev)

# %%
prompt_responses.merge(photos, on = 'asset_id', how = 'inner')
# Out:
#                datetime_created  asset_id labeler_source labeler_id  \
# 0    2025-01-22 17:16:18.020075    641255       Internal      Steve
# 1    2025-01-03 18:57:06.656001    712544       Internal      Steve
# 2    2025-01-03 19:02:00.570005    635034       Internal      Steve
# 3    2025-01-03 19:05:11.937417    632305       Internal      Steve
# 4    2025-01-22 17:16:51.642474    758183       Internal      Steve
# ...                         ...       ...            ...        ...
# 7906 2026-04-20 20:31:01.065656   1059198       Internal       Noah
# 7907 2026-04-20 20:31:02.713691   9987318       Internal       Noah
# 7908 2026-04-20 20:31:07.424643   8826399       Internal       Noah
# 7909 2026-04-20 20:31:20.783766   7365327       Internal       Noah
# 7910 2026-04-20 20:31:21.512063  10087663       Internal       Noah
#
#       labeler_count      task_type_x  rule_index_x prompt_response      id  \
# ...
