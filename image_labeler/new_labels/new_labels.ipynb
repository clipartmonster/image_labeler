# %%
import pandas as pd
import numpy as np

import random
import string
import os
import boto3
from sqlalchemy import text, create_engine
import requests

from datetime import datetime, timedelta
import random

import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

from concurrent.futures import ThreadPoolExecutor, as_completed

import time
import random
from io import BytesIO

# %%
def download_and_upload(row, label_directory, batch_id):
    index = row.name  # If using iterrows()
    if not row.image_link.startswith('http'):
        return None

    try:
        # Random sleep between 0.5 and 2.5 seconds
        time.sleep(random.uniform(0.5, 2.5))

        response = requests.get(row.image_link, verify=False, timeout=10)
        if response.status_code == 200:
            file_name = f"{row.asset_id}.jpg"
            file_path = os.path.join(label_directory, file_name)
            
            with open(file_path, 'wb') as f:
                f.write(response.content)

            s3.upload_file(file_path, 'clip-art-monster-images-for-labeling', f"batch_{batch_id}/{file_name}")
            return index
        else:
            print(f"[{index}] Failed: Status code {response.status_code}")
    except Exception as e:
        print(f"[{index}] Exception: {e}")
    return None

db_connection_string = "postgresql+pg8000://clipart_monster_db_user:iV0BUFPv0rMLu5MKVXesLlvFT3E6MneJ@dpg-cocp8eq0si5c73an4rp0-a.ohio-postgres.render.com/clipart_monster_db_prod"
db_connection_string_dev = "postgresql+pg8000://clipart_monster_db_user:iV0BUFPv0rMLu5MKVXesLlvFT3E6MneJ@dpg-cocp8eq0si5c73an4rp0-a.ohio-postgres.render.com/clipart_monster_db"

# %%
engine = create_engine(db_connection_string)
engine_dev = create_engine(db_connection_string_dev)

# %%
# Optimize DB connections: engines created only once; use context managers to ensure connections are closed.
# Use SQL to filter on the DB side whenever possible to reduce memory/transfer.
# Reduce method chaining with multiple .query() for readability.

engine = create_engine(db_connection_string)
engine_dev = create_engine(db_connection_string_dev)

# Use context manager for connections to ensure proper cleanup.
with engine.connect() as connection_prod:
    # SQL WHERE clause filters assets with s3==True
    asset_data = pd.read_sql(
        'SELECT asset_id, image_link FROM "content"."assets" WHERE s3 = TRUE',
        connection_prod
    )

    # Directly select only relevant columns for image links (already done above)
    image_links = asset_data.copy()  # already filtered by SQL

    # Load model_scores and filter in SQL for performance
    model_scores_query = '''
        SELECT *
        FROM "model_predictions"."rule_labels"
        WHERE 
            task_type = \'color_fill_type\' AND
            rule_index = 1 AND
            model_version = \'CF1_0.01\' AND
            probability > 0.4 AND
            probability < 0.6
    '''
    filtered_assets = pd.read_sql(model_scores_query, connection_prod)

# Get the table that contains all images available for labeling using a context manager
with engine_dev.connect() as connection_dev:
    label_image_table = pd.read_sql('SELECT * FROM "label_data.selected_assets"', connection_dev)

# %%
######################
#increment batch id by 1
batch_id = np.max(label_image_table.batch_id) + 1

######################
#remove already selected assets
is_selected= label_image_table \
    .filter(['asset_id']) \
    .assign(selected = 'yes')

avaiable_assets = filtered_assets \
    .merge(image_links, on = 'asset_id', how = 'left') \
    .merge(is_selected, on = 'asset_id', how = 'left') \
    .query('selected != "yes"')


#set the label directory
label_directory =  'C:/Users/noahs/Documents/labeling/batch_' + str(batch_id) + '/'

os.makedirs(label_directory)

# %%
avaiable_assets
# Out:
#        asset_id        task_type  rule_index  probability  label  \
# 1       2092088  color_fill_type           1     0.550780      1
# 3        304929  color_fill_type           1     0.415269      0
# 4        324392  color_fill_type           1     0.482081      0
# 5        447292  color_fill_type           1     0.468206      0
# 7        482136  color_fill_type           1     0.486783      0
# ...         ...              ...         ...          ...    ...
# 21281   8233562  color_fill_type           1     0.577035      1
# 21282   8234865  color_fill_type           1     0.433484      0
# 21283   8235383  color_fill_type           1     0.417384      0
# 21284   8237887  color_fill_type           1     0.430067      0
# 21285   8239448  color_fill_type           1     0.599022      1
#
#       model_version  created_at  \
# 1          CF1_0.01  2025-09-17
# 3          CF1_0.01  2025-09-17
# 4          CF1_0.01  2025-09-17
# 5          CF1_0.01  2025-09-17
# 7          CF1_0.01  2025-09-17
# ...             ...         ...
# 21281      CF1_0.01  2025-12-20
# 21282      CF1_0.01  2025-12-20
# 21283      CF1_0.01  2025-12-20
# 21284      CF1_0.01  2025-12-20
# 21285      CF1_0.01  2025-12-20
#
#                                               image_link selected
# 1      https://t3.ftcdn.net/jpg/10/46/18/50/360_F_104...      NaN
# 3      https://t3.ftcdn.net/jpg/05/86/42/86/360_F_586...      NaN
# 4      https://clipart.com/thumbs.php?f=/776/batch_23...      NaN
# 5      https://image.shutterstock.com/z/stock-photo-s...      NaN
# 7      https://image.shutterstock.com/z/stock-photo-i...      NaN
# ...                                                  ...      ...
# 21281  https://c7.alamy.com/comp/2JNGCRX/illustration...      NaN
# 21282  https://c7.alamy.com/comp/2XTXFB9/atatrk-silho...      NaN
# 21283  https://image.shutterstock.com/z/stock-vector-...      NaN
# 21284  https://images.rawpixel.com/image_png_800/cHJp...      NaN
# 21285  https://image.shutterstock.com/z/stock-photo-a...      NaN
#
# [20756 rows x 9 columns]

# %%
######################
#build asset table

date = datetime.now().strftime("%Y-%m-%d")

selected_assets = avaiable_assets \
    .sample(20000) \
    .filter(['asset_id','image_link']) \
    .assign(batch_id = batch_id) \
    .assign(date_created = date) \
    .assign(label_count = 0) \
    .assign(clip_art_type = 0) \
    .assign(count = 0) \
    .assign(line_width = 0) \
    .assign(color_depth = 0) \
    .assign(primary_color = 0) \
    .assign(model_batch = 'CO1_0.01') \
    .reset_index() \
    .drop(['index'],axis = 1)
        

# successful_downloads = []
# with ThreadPoolExecutor(max_workers=20) as executor:
#     futures = [
#         executor.submit(download_and_upload, row, label_directory, batch_id)
#         for _, row in selected_assets.iterrows()
#     ]

#     for i, future in enumerate(as_completed(futures), 1):
#         result = future.result()
#         print(f"{i} out of {len(selected_assets)}")
#         if result is not None:
#             successful_downloads.append(result)
            
# # Filter the DataFrame to keep only the rows with successful downloads
# selected_assets = selected_assets.loc[successful_downloads]

# # Reset the index if needed
# selected_assets = selected_assets.reset_index(drop=True)

temp = selected_assets.copy()

temp['sub_batch'] = ((temp.index // 5) + 1).astype(int)
temp['large_sub_batch'] = ((temp.index // 500) + 1).astype(int)
temp['asset_type'] = 'undetermined'
temp['color_type'] = 'undetermined'

# %%
temp
# Out:
#        asset_id                                         image_link  batch_id  \
# 0       6419942  https://t4.ftcdn.net/jpg/04/43/36/51/360_F_443...        12
# 1        723028  https://t4.ftcdn.net/jpg/10/04/61/81/360_F_100...        12
# 2       7834087  https://image.shutterstock.com/z/stock-vector-...        12
# 3       6361649  https://t3.ftcdn.net/jpg/09/81/90/38/360_F_981...        12
# 4       3041012  https://t3.ftcdn.net/jpg/11/25/17/66/360_F_112...        12
# ...         ...                                                ...       ...
# 19995   7594241  https://images.freeimages.com/variants/PwuvSYR...        12
# 19996   7880077  https://img.b2bpic.net/premium-photo/knitted-t...        12
# 19997   7620753  https://e7.pngegg.com/pngimages/455/708/png-cl...        12
# 19998   7935856  https://img.b2bpic.net/premium-photo/colorful-...        12
# 19999   7929680  https://img.b2bpic.net/premium-vector/hello-sp...        12
#
#       date_created  label_count  clip_art_type  count  line_width  \
# 0       2025-12-20            0              0      0           0
# 1       2025-12-20            0              0      0           0
# 2       2025-12-20            0              0      0           0
# 3       2025-12-20            0              0      0           0
# 4       2025-12-20            0              0      0           0
# ...            ...          ...            ...    ...         ...
# 19995   2025-12-20            0              0      0           0
# 19996   2025-12-20            0              0      0           0
# 19997   2025-12-20            0              0      0           0
# 19998   2025-12-20            0              0      0           0
# 19999   2025-12-20            0              0      0           0
#
#        color_depth  primary_color model_batch  sub_batch  large_sub_batch  \
# 0                0              0    CO1_0.01          1                1
# 1                0              0    CO1_0.01          1                1
# 2                0              0    CO1_0.01          1                1
# 3                0              0    CO1_0.01          1                1
# 4                0              0    CO1_0.01          1                1
# ...            ...            ...         ...        ...              ...
# 19995            0              0    CO1_0.01       4000               40
# 19996            0              0    CO1_0.01       4000               40
# 19997            0              0    CO1_0.01       4000               40
# 19998            0              0    CO1_0.01       4000               40
# 19999            0              0    CO1_0.01       4000               40
#
#          asset_type    color_type
# 0      undetermined  undetermined
# 1      undetermined  undetermined
# 2      undetermined  undetermined
# 3      undetermined  undetermined
# 4      undetermined  undetermined
# ...             ...           ...
# 19995  undetermined  undetermined
# 19996  undetermined  undetermined
# 19997  undetermined  undetermined
# 19998  undetermined  undetermined
# 19999  undetermined  undetermined
#
# [20000 rows x 15 columns]

# %%
with engine_dev.begin() as conn:  # begin() auto-commits; faster/cleaner than connect() for writes
    temp.to_sql(
        "label_data.selected_assets",
        con=conn,
        if_exists="append",
        index=False,
        chunksize=10_000
        )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:3246, in Engine.begin(self)
#    3245 with conn.begin():
# -> 3246     yield conn
#
# Cell In[21], line 2
#       1 with engine_dev.begin() as conn:  # begin() auto-commits; faster/cleaner than connect() for writes
# ----> 2     temp.to_sql(
#       3         "label_data.selected_assets",
#       4         con=conn,
#       5         if_exists="append",
#       6         index=False,
#       7         chunksize=10_000
#       8         )
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:2008, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
# -> 2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    2011     if_exists=if_exists,
#    2012     index=index,
#    2013     index_label=index_label,
#    2014     schema=schema,
#    2015     dtype=dtype,
#    2016 )
#    2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    (...)
#    2027     **engine_kwargs,
#    2028 )
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:1912, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1902 table = SQLTable(
#    1903     name,
#    1904     self,
#    (...)
#    1910     dtype=dtype,
#    1911 )
# -> 1912 table.create()
#    1913 return table
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:995, in SQLTable.create(self)
#     994 else:
# --> 995     self._execute_create()
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:981, in SQLTable._execute_create(self)
#     980 with self.pd_sql.run_transaction():
# --> 981     self.table.create(bind=self.pd_sql.con)
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\sql\schema.py:1288, in Table.create(self, bind, checkfirst)
#    1277 """Issue a ``CREATE`` statement for this
#    1278 :class:`_schema.Table`, using the given
#    1279 :class:`.Connection` or :class:`.Engine`
#    (...)
#    1285
#    1286 """
# -> 1288 bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:2461, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2455 """run a DDL visitor.
#    2456
#    2457 This method is only here so that the MockConnection can change the
#    2458 options given to the visitor so that "checkfirst" is skipped.
#    2459
#    2460 """
# -> 2461 visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\sql\visitors.py:664, in ExternalTraversal.traverse_single(self, obj, **kw)
#     663 if meth:
# --> 664     return meth(obj, **kw)
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\sql\ddl.py:956, in SchemaGenerator.visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     949     include_foreign_key_constraints = None
#     951 CreateTable(
#     952     table,
#     953     include_foreign_key_constraints=(
#     954         include_foreign_key_constraints
#     955     ),
# --> 956 )._invoke_with(self.connection)
#     958 if hasattr(table, "indexes"):
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\sql\ddl.py:314, in ExecutableDDLElement._invoke_with(self, bind)
#     313 if self._should_execute(self.target, bind):
# --> 314     return bind.execute(self)
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1422, in Connection.execute(self, statement, parameters, execution_options)
#    1421 else:
# -> 1422     return meth(
#    1423         self,
#    1424         distilled_parameters,
#    1425         execution_options or NO_OPTIONS,
#    1426     )
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\sql\ddl.py:180, in ExecutableDDLElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     177 def _execute_on_connection(
#     178     self, connection, distilled_params, execution_options
#     179 ):
# --> 180     return connection._execute_ddl(
#     181         self, distilled_params, execution_options
#     182     )
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1533, in Connection._execute_ddl(self, ddl, distilled_parameters, execution_options)
#    1530 compiled = ddl.compile(
#    1531     dialect=dialect, schema_translate_map=schema_translate_map
#    1532 )
# -> 1533 ret = self._execute_context(
#    1534     dialect,
#    1535     dialect.execution_ctx_cls._init_ddl,
#    1536     compiled,
#    1537     None,
#    1538     exec_opts,
#    1539     compiled,
#    1540 )
#    1541 if self._has_events or self.engine._has_events:
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1850, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1849 else:
# -> 1850     return self._exec_single_context(
#    1851         dialect, context, statement, parameters
#    1852     )
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1990, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1989 except BaseException as e:
# -> 1990     self._handle_dbapi_exception(
#    1991         e, str_statement, effective_parameters, cursor, context
#    1992     )
#    1994 return result
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:2360, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2359         assert exc_info[1] is not None
# -> 2360         raise exc_info[1].with_traceback(exc_info[2])
#    2361 finally:
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1971, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1970     if not evt_handled:
# -> 1971         self.dialect.do_execute(
#    1972             cursor, str_statement, effective_parameters, context
#    1973         )
#    1975 if self._has_events or self.engine._has_events:
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\default.py:919, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     918 def do_execute(self, cursor, statement, parameters, context=None):
# --> 919     cursor.execute(statement, parameters)
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pg8000\legacy.py:270, in Cursor.execute(self, operation, args, stream)
#     269     else:
# --> 270         raise e
#     271 except DatabaseError as e:
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pg8000\legacy.py:253, in Cursor.execute(self, operation, args, stream)
#     252 if len(args) == 0 and stream is None:
# --> 253     self._context = self._c.execute_simple(operation)
#     254 else:
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pg8000\core.py:694, in CoreConnection.execute_simple(self, statement)
#     693 _flush(self._sock)
# --> 694 self.handle_messages(context)
#     696 return context
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pg8000\core.py:841, in CoreConnection.handle_messages(self, context)
#     839     code, data_len = ci_unpack(_read(self._sock, 5))
# --> 841     self.message_types[code](_read(self._sock, data_len - 4), context)
#     843 if context.error is not None:
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pg8000\core.py:833, in CoreConnection.handle_DATA_ROW(self, data, context)
#     832     row.append(v)
# --> 833 context.rows.append(row)
#
# AttributeError: 'NoneType' object has no attribute 'append'
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1131, in Connection._rollback_impl(self)
#    1130 try:
# -> 1131     self.engine.dialect.do_rollback(self.connection)
#    1132 except BaseException as e:
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\default.py:693, in DefaultDialect.do_rollback(self, dbapi_connection)
#     692 def do_rollback(self, dbapi_connection):
# --> 693     dbapi_connection.rollback()
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pg8000\legacy.py:502, in Connection.rollback(self)
#     501     return
# --> 502 self.execute_unnamed("rollback")
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pg8000\core.py:718, in CoreConnection.execute_unnamed(self, statement, vals, oids, stream)
#     717 self.send_BIND(NULL_BYTE, params)
# --> 718 self.handle_messages(context)
#     719 self.send_EXECUTE()
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pg8000\core.py:844, in CoreConnection.handle_messages(self, context)
#     843 if context.error is not None:
# --> 844     raise context.error
#
# DatabaseError: {'S': 'ERROR', 'V': 'ERROR', 'C': '42P07', 'M': 'relation "label_data.selected_assets" already exists', 'F': 'heap.c', 'L': '1160', 'R': 'heap_create_with_catalog'}
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 with engine_dev.begin() as conn:  # begin() auto-commits; faster/cleaner than connect() for writes
#       2     temp.to_sql(
#       3         "label_data.selected_assets",
#       4         con=conn,
#    (...)
#       7         chunksize=10_000
#       8         )
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     153     value = typ()
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#     160     return exc is not value
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:3245, in Engine.begin(self)
#    3219 """Return a context manager delivering a :class:`_engine.Connection`
#    3220 with a :class:`.Transaction` established.
#    3221
#    (...)
#    3242
#    3243 """
#    3244 with self.connect() as conn:
# -> 3245     with conn.begin():
#    3246         yield conn
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\util.py:162, in TransactionalContext.__exit__(self, type_, value, traceback)
#     160     else:
#     161         if self._rollback_can_be_called():
# --> 162             self.rollback()
#     163 finally:
#     164     if not out_of_band_exit:
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:2612, in Transaction.rollback(self)
#    2595 """Roll back this :class:`.Transaction`.
#    2596
#    2597 The implementation of this may vary based on the type of transaction in
#    (...)
#    2609
#    2610 """
#    2611 try:
# -> 2612     self._do_rollback()
#    2613 finally:
#    2614     assert not self.is_active
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:2731, in RootTransaction._do_rollback(self)
#    2730 def _do_rollback(self) -> None:
# -> 2731     self._close_impl(try_deactivate=True)
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:2714, in RootTransaction._close_impl(self, try_deactivate)
#    2712 try:
#    2713     if self.is_active:
# -> 2714         self._connection_rollback_impl()
#    2716     if self.connection._nested_transaction:
#    2717         self.connection._nested_transaction._cancel()
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:2706, in RootTransaction._connection_rollback_impl(self)
#    2705 def _connection_rollback_impl(self) -> None:
# -> 2706     self.connection._rollback_impl()
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1133, in Connection._rollback_impl(self)
#    1131     self.engine.dialect.do_rollback(self.connection)
#    1132 except BaseException as e:
# -> 1133     self._handle_dbapi_exception(e, None, None, None, None)
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:2357, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2355 elif should_wrap:
#    2356     assert sqlalchemy_exception is not None
# -> 2357     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2358 else:
#    2359     assert exc_info[1] is not None
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1131, in Connection._rollback_impl(self)
#    1129         self._log_info("ROLLBACK")
#    1130 try:
# -> 1131     self.engine.dialect.do_rollback(self.connection)
#    1132 except BaseException as e:
#    1133     self._handle_dbapi_exception(e, None, None, None, None)
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\default.py:693, in DefaultDialect.do_rollback(self, dbapi_connection)
#     692 def do_rollback(self, dbapi_connection):
# --> 693     dbapi_connection.rollback()
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pg8000\legacy.py:502, in Connection.rollback(self)
#     500 if not self._in_transaction:
#     501     return
# --> 502 self.execute_unnamed("rollback")
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pg8000\core.py:718, in CoreConnection.execute_unnamed(self, statement, vals, oids, stream)
#     716 params = make_params(self.py_types, vals)
#     717 self.send_BIND(NULL_BYTE, params)
# --> 718 self.handle_messages(context)
#     719 self.send_EXECUTE()
#     721 _write(self._sock, SYNC_MSG)
#
# File c:\Users\noahs\AppData\Local\Programs\Python\Python311\Lib\site-packages\pg8000\core.py:844, in CoreConnection.handle_messages(self, context)
#     841     self.message_types[code](_read(self._sock, data_len - 4), context)
#     843 if context.error is not None:
# --> 844     raise context.error
#
# DatabaseError: (pg8000.exceptions.DatabaseError) {'S': 'ERROR', 'V': 'ERROR', 'C': '42P07', 'M': 'relation "label_data.selected_assets" already exists', 'F': 'heap.c', 'L': '1160', 'R': 'heap_create_with_catalog'}
# (Background on this error at: https://sqlalche.me/e/20/4xp6)
